# %%
from __future__ import division
import pandas as pd
import numpy as np

churn_df = pd.read_csv(r"C:\Users\cxb0254\Documents\Cursos_dat-academy\Pracice_Python\Churn.csv", sep = ';')
col_names = churn_df.columns.tolist()

print ("Column names:")
print (col_names)

churn_df.head(6)
# Out:
# Column names:
# ['Account Length', 'VMail Message', 'Day Mins', 'Eve Mins', 'Night Mins', 'Intl Mins', 'CustServ Calls', 'Churn', "Int'l Plan", 'VMail Plan', 'Day Calls', 'Day Charge', 'Eve Calls', 'Eve Charge', 'Night Calls', 'Night Charge', 'Intl Calls', 'Intl Charge']
#    Account Length  VMail Message  Day Mins  Eve Mins  Night Mins  Intl Mins  \
# 0             128             25     265.1     197.4       244.7       10.0
# 1             107             26     161.6     195.5       254.4       13.7
# 2             137              0     243.4     121.2       162.6       12.2
# 3              84              0     299.4      61.9       196.9        6.6
# 4              75              0     166.7     148.3       186.9       10.1
# 5             118              0     223.4     220.6       203.9        6.3
#
#    CustServ Calls  Churn  Int'l Plan  VMail Plan  Day Calls  Day Charge  \
# 0               1      0           0           1        110       45.07
# ...

# %%
y = churn_df['Churn']
print("Churns positivos: ", sum(y))
print("Churns negativos: ", y.shape[0] - sum(y))

features = churn_df.columns
X = churn_df.as_matrix().astype(np.float)
print("Hay %d ejemplos y %d variables" %X.shape)
# Out:
# Churns positivos:  483
# Churns negativos:  2850
# Hay 3333 ejemplos y 18 variables
# C:\Users\cxb0254\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.

# %% [markdown]
# ## RANDOM FOREST

# %%
np.random.seed(10)
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import metrics

# %%
X_train, X_test = X[0:2500], X[2501:]
y_train, y_test = y[0:2500], y[2501:]
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

n_estimator = 1
rf = RandomForestClassifier(max_depth=30, n_estimators=n_estimator)
rf.fit(X_train, y_train)
yhat = rf.predict(X_test)
print("Report (1 árbol): \n", metrics.classification_report(y_test,yhat))

n_estimator = 10
rf = RandomForestClassifier(max_depth=30, n_estimators=n_estimator)
rf.fit(X_train, y_train)
yhat = rf.predict(X_test)
print("Report (10 árboles): \n", metrics.classification_report(y_test,yhat))

n_estimator = 100
rf = RandomForestClassifier(max_depth=30, n_estimators=n_estimator)
rf.fit(X_train, y_train)
yhat = rf.predict(X_test)
print("Report (100 árboles): \n", metrics.classification_report(y_test,yhat))
# Out:
# Report (1 árbol):
#                precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       696
#            1       0.95      0.96      0.96       136
#
#    micro avg       0.99      0.99      0.99       832
#    macro avg       0.97      0.98      0.97       832
# weighted avg       0.99      0.99      0.99       832
#
# Report (10 árboles):
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       696
#            1       1.00      1.00      1.00       136
#
#    micro avg       1.00      1.00      1.00       832
#    macro avg       1.00      1.00      1.00       832
# weighted avg       1.00      1.00      1.00       832
#
# Report (100 árboles):
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       696
#            1       1.00      1.00      1.00       136
#
#    micro avg       1.00      1.00      1.00       832
# ...
