# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import PolynomialFeatures, Imputer
from sklearn.linear_model import Lasso,Ridge
from sklearn.pipeline import make_pipeline

# %%
datos = pd.read_csv('https://raw.githubusercontent.com/hjhuney/Data/master/AmesHousing/train.csv')
datos.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
datos = datos._get_numeric_data()

# %%
datos.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1    ...      WoodDeckSF  OpenPorchSF  \
# 0          2003       196.0         706    ...               0           61
# 1          1976         0.0         978    ...             298            0
# 2          2002       162.0         486    ...               0           42
# 3          1970         0.0         216    ...               0           35
# 4          2000       350.0         655    ...             192           84
#
# ...

# %%
imputer = Imputer(missing_values='NaN', strategy='mean', axis=0)
imputer = imputer.fit(datos.iloc[:,:])
df = imputer.transform(datos.iloc[:,:])
data = pd.DataFrame(df)
data.columns = datos.columns

# %%
data.head()
# Out:
#     Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0  1.0        60.0         65.0   8450.0          7.0          5.0     2003.0
# 1  2.0        20.0         80.0   9600.0          6.0          8.0     1976.0
# 2  3.0        60.0         68.0  11250.0          7.0          5.0     2001.0
# 3  4.0        70.0         60.0   9550.0          7.0          5.0     1915.0
# 4  5.0        60.0         84.0  14260.0          8.0          5.0     2000.0
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1    ...      WoodDeckSF  OpenPorchSF  \
# 0        2003.0       196.0       706.0    ...             0.0         61.0
# 1        1976.0         0.0       978.0    ...           298.0          0.0
# 2        2002.0       162.0       486.0    ...             0.0         42.0
# 3        1970.0         0.0       216.0    ...             0.0         35.0
# 4        2000.0       350.0       655.0    ...           192.0         84.0
#
# ...

# %% [markdown]
# ## Split the data into 'train data' and 'test data'

# %%
from sklearn.model_selection import train_test_split

X = data.iloc[:,:-1]
y = data.SalePrice

X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=9, train_size=0.5)

# %% [markdown]
# ## Perform Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

regressor = LinearRegression() # Linear model
regressor.fit(X_train,y_train)
y_pred = regressor.predict(X_test)
mean_squared_error(y_test, y_pred)
# Out:
# 1307077923.6233084

# %% [markdown]
# ## Perform Lasso Regression (L1)

# %%
lasso_model = Lasso(alpha = 140)
lasso_model.fit(X_train,y_train) #Lasso model
y_pred = lasso_model.predict(X_test)
mean_squared_error(y_test, y_pred)
# Out:
# 1290255632.549818

# %% [markdown]
# ## Ridge Regression (L2)

# %%
ridge_model = Ridge(alpha=0.00002, max_iter=100000, random_state=9)
ridge_model.fit(X_train,y_train) # Ridge model
y_pred = ridge_model.predict(X_test)
mean_squared_error(y_test,y_pred)
# Out:
# 1307077877.9792123
